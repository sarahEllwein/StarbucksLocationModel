# %% [markdown]
# # Starbucks Stores Analysis

# %%
# Housekeeping
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Import datasets
popURL = 'https://www2.census.gov/programs-surveys/popest/datasets/2010-2017/cities/totals/sub-est2017_all.csv'

starbucks = pd.read_csv('data/directory.csv')
income = pd.read_csv('data/archive/kaggle_income.csv', encoding='cp1252')
population = pd.read_csv(popURL, encoding='cp1252')
demographic = pd.read_csv('data/demo.csv', encoding='cp1252')

# %% [markdown]
# ***

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# Data Constraints:
# - Both Starbucks and US datasets published in 2017.
# - Starbucks store locations limited to US country.
# - Starbucks store limited to Starbucks brand (no Teavana)
# - Exclude Puerto Rico from US datasets

# %% [markdown]
# ### Starbucks Dataset

# %%
starbucks = starbucks.query("Brand == 'Starbucks'").query("Country == 'US'")
starbucks = starbucks.drop(columns=["Brand", "Store Name", "Ownership Type", "Street Address","Phone Number","Timezone", "Postcode", "Country"])
starbucks = starbucks.rename(columns={'State/Province' : 'State'})

# %% [markdown]
# ### US County Income Dataset

# %%
# income = income[["State_Name","State_ab","County","City","Median"]]
income
# Out:
#             id  State_Code   State_Name State_ab              County  \
# 0      1011000           1      Alabama       AL       Mobile County
# 1      1011010           1      Alabama       AL      Barbour County
# 2      1011020           1      Alabama       AL       Shelby County
# 3      1011030           1      Alabama       AL       Mobile County
# 4      1011040           1      Alabama       AL       Mobile County
# ...        ...         ...          ...      ...                 ...
# 32521   720296          72  Puerto Rico       PR  Adjuntas Municipio
# 32522  7202966          72  Puerto Rico       PR  Adjuntas Municipio
# 32523  7202976          72  Puerto Rico       PR  Adjuntas Municipio
# 32524  7202986          72  Puerto Rico       PR  Adjuntas Municipio
# 32525  7202996          72  Puerto Rico       PR  Adjuntas Municipio
#
#                  City            Place   Type Primary  Zip_Code Area_Code  \
# 0           Chickasaw   Chickasaw city   City   place     36611       251
# 1          Louisville        Clio city   City   place     36048       334
# 2          Columbiana  Columbiana city   City   place     35051       205
# 3             Satsuma      Creola city   City   place     36572       251
# 4      Dauphin Island   Dauphin Island   Town   place     36528       251
# ...               ...              ...    ...     ...       ...       ...
# 32521        Guaynabo         Adjuntas  Track   Track       970       787
# 32522          Aguada         Adjuntas  Track   Track       602       787
# 32523          Aguada         Adjuntas  Track   Track       602       787
# 32524          Aguada         Adjuntas  Track   Track       602       787
# 32525       Aguadilla         Adjuntas  Track   Track       603       787
#
#           ALand     AWater        Lat        Lon   Mean  Median  Stdev  \
# 0      10894952     909156  30.771450 -88.079697  38773   30506  33101
# 1      26070325      23254  31.708516 -85.611039  37725   19528  43789
# 2      44835274     261034  33.191452 -86.615618  54606   31930  57348
# 3      36878729    2374530  30.874343 -88.009442  63919   52814  47707
# 4      16204185  413605152  30.250913 -88.171268  77948   67225  54270
# ...         ...        ...        ...        ...    ...     ...    ...
# 32521    589417       1691  18.397925 -66.130633  30649   13729  37977
# 32522   1801613     795887  18.385424 -67.203310  15520    9923  15541
# 32523  11031227          0  18.356565 -67.180686  41933   34054  31539
# 32524         0   33597561  18.412041 -67.213413      0       0      0
# 32525   6476604    2717115  18.478094 -67.160453  28049   20229  33333
#
#              sum_w
# 0      1638.260513
# 1       258.017685
# 2       926.031000
# 3       378.114619
# 4       282.320328
# ...            ...
# 32521  1321.278082
# 32522   238.813450
# 32523   313.551070
# 32524     0.000000
# 32525   512.884803
#
# [32526 rows x 19 columns]

# %% [markdown]
# ### US County Population Dataset

# %%
population = population.loc[population['SUMLEV'] == 162]
population = population[["NAME", "STNAME", "POPESTIMATE2017"]]
population["NAME"] = population["NAME"].apply(lambda x: ' '.join(x.split()[0:-1]))

# %% [markdown]
# ### US County Demographic Dataset

# %%
demographic
# Out:
#       Unnamed: 0  CountyId        State               County  TotalPop    Men  \
# 0              0      1001      Alabama       Autauga County     55036  26899
# 1              1      1003      Alabama       Baldwin County    203360  99527
# 2              2      1005      Alabama       Barbour County     26201  13976
# 3              3      1007      Alabama          Bibb County     22580  12251
# 4              4      1009      Alabama        Blount County     57667  28490
# ...          ...       ...          ...                  ...       ...    ...
# 3215        3215     72145  Puerto Rico  Vega Baja Municipio     54754  26269
# 3216        3216     72147  Puerto Rico    Vieques Municipio      8931   4351
# 3217        3217     72149  Puerto Rico   Villalba Municipio     23659  11510
# 3218        3218     72151  Puerto Rico    Yabucoa Municipio     35025  16984
# 3219        3219     72153  Puerto Rico      Yauco Municipio     37585  18052
#
#        Women  Hispanic  White  Black  ...  Walk  OtherTransp  WorkAtHome  \
# 0      28137       2.7   75.4   18.9  ...   0.6          1.3         2.5
# 1     103833       4.4   83.1    9.5  ...   0.8          1.1         5.6
# 2      12225       4.2   45.7   47.8  ...   2.2          1.7         1.3
# 3      10329       2.4   74.6   22.0  ...   0.3          1.7         1.5
# 4      29177       9.0   87.4    1.5  ...   0.4          0.4         2.1
# ...      ...       ...    ...    ...  ...   ...          ...         ...
# 3215   28485      96.7    3.1    0.1  ...   1.4          0.6         0.9
# 3216    4580      95.7    4.0    0.0  ...   5.0          0.0         1.7
# 3217   12149      99.7    0.2    0.1  ...   2.1          0.0         2.8
# 3218   18041      99.9    0.1    0.0  ...   1.4          1.8         0.1
# 3219   19533      99.8    0.2    0.0  ...   1.7          0.1         5.0
#
#       MeanCommute  Employed  PrivateWork  PublicWork  SelfEmployed  \
# 0            25.8     24112         74.1        20.2           5.6
# 1            27.0     89527         80.7        12.9           6.3
# 2            23.4      8878         74.1        19.1           6.5
# 3            30.0      8171         76.0        17.4           6.3
# 4            35.0     21380         83.9        11.9           4.0
# ...           ...       ...          ...         ...           ...
# 3215         31.6     14234         76.2        19.3           4.3
# 3216         14.9      2927         40.7        40.9          18.4
# 3217         28.4      6873         59.2        30.2          10.4
# 3218         30.5      7878         62.7        30.9           6.3
# 3219         24.4      8995         66.4        28.7           5.0
#
#       FamilyWork  Unemployment
# 0            0.1           5.2
# 1            0.1           5.5
# 2            0.3          12.4
# 3            0.3           8.2
# 4            0.1           4.9
# ...          ...           ...
# 3215         0.2          16.8
# 3216         0.0          12.8
# 3217         0.2          24.8
# 3218         0.0          25.4
# 3219         0.0          24.0
#
# [3220 rows x 38 columns]

# %% [markdown]
# ### Merge Data

# %%
data = pd.merge(income, population, left_on=["State_Name","City"], right_on=["STNAME", "NAME"]).drop(columns=["NAME","STNAME"])
data = pd.merge(starbucks, data, how='right', left_on=["State", "City"], right_on=["State_ab","City"]).drop(columns=['State_Name','State'])
data = data.rename(columns={"Longitude":"Starbucks Lon", "Latitude":"Starbucks Lat",\
                            "State_ab":"State",\
                            "POPESTIMATE2017":"Population"})
data = data[~data['Store Number'].duplicated() | data['Store Number'].isnull()]
data
# Out:
#        Store Number          City  Starbucks Lon  Starbucks Lat       id  \
# 0               NaN     Chickasaw            NaN            NaN  1011000
# 1               NaN     Chickasaw            NaN            NaN   102826
# 2               NaN    Louisville            NaN            NaN  1011010
# 3               NaN    Louisville            NaN            NaN    10246
# 4               NaN    Columbiana            NaN            NaN  1011020
# ...             ...           ...            ...            ...      ...
# 427548          NaN      Pinedale            NaN            NaN  5602464
# 427549          NaN   Green River            NaN            NaN  5602474
# 427550          NaN         Lyman            NaN            NaN  5602514
# 427551          NaN       Worland            NaN            NaN  5602534
# 427552          NaN  Diamondville            NaN            NaN   560274
#
#         State_Code State          County            Place   Type  ...  \
# 0                1    AL   Mobile County   Chickasaw city   City  ...
# 1                1    AL  Autauga County     Autaugaville  Track  ...
# 2                1    AL  Barbour County        Clio city   City  ...
# 3                1    AL  Autauga County     Autaugaville  Track  ...
# 4                1    AL   Shelby County  Columbiana city   City  ...
# ...            ...   ...             ...              ...    ...  ...
# 427548          56    WY   Albany County     Laramie city  Track  ...
# 427549          56    WY   Albany County     Laramie city  Track  ...
# 427550          56    WY   Albany County     Laramie city  Track  ...
# 427551          56    WY   Albany County     Laramie city  Track  ...
# 427552          56    WY   Albany County     Laramie city  Track  ...
#
#        Area_Code       ALand     AWater        Lat         Lon    Mean  \
# 0            251    10894952     909156  30.771450  -88.079697   38773
# 1            251      981169          0  30.761878  -88.088617   26337
# 2            334    26070325      23254  31.708516  -85.611039   37725
# 3            334   517008078     983621  31.922275  -85.449831   36939
# 4            205    44835274     261034  33.191452  -86.615618   54606
# ...          ...         ...        ...        ...         ...     ...
# 427548       307  6178831172  114671144  42.957147 -109.651015   94204
# 427549       307     1500340          0  41.497363 -109.456039  105562
# 427550       307  2953929736    5101790  41.295517 -110.323344   67374
# 427551       307     1993203          0  44.014369 -107.956379   61427
# 427552       307   120154805      12706  41.819843 -110.556212   78640
#
#         Median  Stdev        sum_w  Population
# 0        30506  33101  1638.260513        5794
# 1        20116  21663   431.982138        5794
# 2        19528  43789   258.017685         468
# 3        27636  33907   870.206244         468
# 4        31930  57348   926.031000        4647
# ...        ...    ...          ...         ...
# 427548   94509  50057   360.402134        1890
# 427549  300000  47849   120.687825       12070
# 427550   70155  36558   197.821970        2067
# 427551  300000  50142   212.561098        5189
# 427552   70752  52272   679.859784         758
#
# [20047 rows x 22 columns]

# %% [markdown]
# ***

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# After merging, 2530 out of 13311 Starbucks store data was lost due to no income and/or population data

# %%
data[~data['Store Number'].isnull()]
# Out:
#         Store Number     City  Starbucks Lon  Starbucks Lat       id  \
# 8       17221-169985  Cullman         -86.84          34.15  1011050
# 26      23672-230991  Gadsden         -86.08          33.99  1011110
# 66      19891-192724   Mobile         -88.18          30.70  1011280
# 67        9970-97273   Mobile         -88.12          30.68  1011280
# 68      11673-105401   Mobile         -88.12          30.67  1011280
# ...              ...      ...            ...            ...      ...
# 427522  21239-210245   Casper        -106.33          42.86  5602364
# 427523    9619-97642   Casper        -106.26          42.85  5602364
# 427524  79668-108627   Casper        -106.27          42.85  5602364
# 427525  11862-103659   Casper        -106.37          42.82  5602364
# 427546  17716-126790     Cody        -109.05          44.52  5602424
#
#         State_Code State          County         Place   Type  ... Area_Code  \
# 8                1    AL  Cullman County    Dodge City   Town  ...       256
# 26               1    AL   Etowah County  Gadsden city   City  ...       256
# 66               1    AL   Mobile County   Mobile city   City  ...       251
# 67               1    AL   Mobile County   Mobile city   City  ...       251
# 68               1    AL   Mobile County   Mobile city   City  ...       251
# ...            ...   ...             ...           ...    ...  ...       ...
# 427522          56    WY   Albany County  Laramie city  Track  ...       307
# 427523          56    WY   Albany County  Laramie city  Track  ...       307
# 427524          56    WY   Albany County  Laramie city  Track  ...       307
# 427525          56    WY   Albany County  Laramie city  Track  ...       307
# 427546          56    WY   Albany County  Laramie city  Track  ...       307
#
#               ALand     AWater        Lat         Lon   Mean  Median  Stdev  \
# 8           8913021      26837  34.045414  -86.882670  50715   42643  35886
# 26         96637272    3060329  34.009563  -86.015643  42251   28811  41397
# 66        361044263  105325210  30.668426  -88.100226  53330   38231  50855
# 67        361044263  105325210  30.668426  -88.100226  53330   38231  50855
# 68        361044263  105325210  30.668426  -88.100226  53330   38231  50855
# ...             ...        ...        ...         ...    ...     ...    ...
# 427522      2836752          0  42.844880 -106.309837  62251   54419  42997
# 427523      2836752          0  42.844880 -106.309837  62251   54419  42997
# 427524      2836752          0  42.844880 -106.309837  62251   54419  42997
# 427525      2836752          0  42.844880 -106.309837  62251   54419  42997
# 427546  16203355191   61215488  44.493910 -109.667578  72151  300000  36256
#
#                sum_w  Population
# 8         173.325959       15385
# 26      10716.139237       35409
# 66      51243.648369      190265
# 67      51243.648369      190265
# 68      51243.648369      190265
# ...              ...         ...
# 427522    480.343657       57814
# 427523    480.343657       57814
# 427524    480.343657       57814
# 427525    480.343657       57814
# 427546    397.880302        9885
#
# [10781 rows x 22 columns]

# %% [markdown]
# ### Number of Starbucks per City

# %%
data['Location'] = data['City'] + ', ' + data['State']
storesPerCity = data.groupby('Location')['Store Number'].count()
storesPerCity = storesPerCity.to_frame().rename(columns={'Store Number':'Total'}).reset_index()

# %% [markdown]
# #### Cities with Starbucks (descending order)

# %%
hasStarbucks = storesPerCity[storesPerCity['Total'] > 0].sort_values('Total', ascending = False)
hasStarbucks
# Out:
#             Location  Total
# 5173    New York, NY    230
# 1340     Chicago, IL    179
# 3993   Las Vegas, NV    153
# 3421     Houston, TX    151
# 6607     Seattle, WA    151
# ...              ...    ...
# 3981   Larchmont, NY      1
# 3975      Lapeer, MI      1
# 3968    Lansdale, PA      1
# 3962     Landrum, SC      1
# 8115  Zionsville, IN      1
#
# [2313 rows x 2 columns]

# %% [markdown]
# #### Number of cities without Starbucks

# %%
noStarbucks = storesPerCity[storesPerCity["Total"] == 0]
len(noStarbucks.index)
# Out:
# 5806

# %%
store_data = pd.merge(storesPerCity, data[["Location", "Median", "Population"]], on=["Location"]).drop_duplicates()
store_data.sort_values('Total', ascending = False)
# Out:
#              Location  Total  Median  Population
# 12247    New York, NY    230   68128     8622698
# 3141      Chicago, IL    179   48321     2716450
# 9431    Las Vegas, NV    153   44734      641676
# 8002      Houston, TX    151  300000     2312717
# 16648     Seattle, WA    151   28154      724745
# ...               ...    ...     ...         ...
# 7187   Greenville, MO      0   53626         485
# 7188   Greenville, MS      0   12655       30686
# 7189   Greenville, MS      0   42369       30686
# 7190   Greenville, MS      0   56999       30686
# 20046      Zwolle, LA      0   26065        1929
#
# [11488 rows x 4 columns]

# %%
store_data.sort_values('Median', ascending = False)
# Out:
#                       Location  Total  Median  Population
# 14512             Portland, TN      0  300000       12697
# 17374  Spring Lake Heights, NJ      0  300000        4618
# 19931              Wyoming, OH      0  300000        8536
# 4176             Covington, WA      4  300000       20916
# 7803         Highland Park, NJ      0  300000       14164
# ...                        ...    ...     ...         ...
# 17009             Sikeston, MO      0       0       16155
# 10635               Manteo, NC      0       0        1435
# 13623            Patterson, LA      0       0        5982
# 6506                Fulton, MO      0       0       12844
# 15190          River Rouge, MI      0       0        7482
#
# [11488 rows x 4 columns]

# %%
store_data['Total'].corr(store_data['Median'])
# Out:
# 0.04472559925275821

# %%
store_data['Total'].corr(store_data['Population'])
# Out:
# 0.8099224080130096

# %% [markdown]
# ***

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Distribution of Number of Starbucks Locations per County

# %% [markdown]
# ### Starbucks Location vs. County Income

# %% [markdown]
# ### Starbucks Location vs. County Population
